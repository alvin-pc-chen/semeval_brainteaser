# %%
import numpy as np

data = []
data.append(np.load('SP_val_question_random.npy', allow_pickle=True))
data.append(np.load('WP_val_question_random.npy', allow_pickle=True))
data.append(np.load('SP-train.npy', allow_pickle=True))
data.append(np.load('WP-train.npy', allow_pickle=True))

for i in range(len(data)):
    print(f"Document {i}")
    print(data[i])
# Out:
# Document 0
# [{'question': 'In a small village, two farmers are working in their fields - a diligent farmer and a lazy farmer. The hardworking farmer is the son of the lazy farmer, but the lazy farmer is not the father of the hardworking farmer. Can you explain this unusual relationship?', 'choice_list': ['The lazy farmer is his mother.', 'The lazy farmer is not a responsible father as he is lazy.', 'The diligent farmer devoted himself to the farm and gradually forgot his father.', 'None of above.']}
# ...

# %%
print(data[0][0])
# Out:
# {'question': 'In a small village, two farmers are working in their fields - a diligent farmer and a lazy farmer. The hardworking farmer is the son of the lazy farmer, but the lazy farmer is not the father of the hardworking farmer. Can you explain this unusual relationship?', 'choice_list': ['The lazy farmer is his mother.', 'The lazy farmer is not a responsible father as he is lazy.', 'The diligent farmer devoted himself to the farm and gradually forgot his father.', 'None of above.']}

# %%
# TODO: structure the trainsets by question \n answers in order
for dat in data[2]:
    print(f"{dat['question']}\n{dat['choice_list']}")
# Out:
# Mr. and Mrs. Mustard have six daughters and each daughter has one brother. But there are only 9 people in the family, how is that possible?
# ['Some daughters get married and have their own family.', 'Each daughter shares the same brother.', 'Some brothers were not loved by family and moved away.', 'None of above.']
# The six daughters of Mr. and Mrs. Mustard each have one brother. However, the family only consists of nine people; how is that possible?
# ['Some brothers were not loved by family and moved away.', 'Some daughters get married and have their own family.', 'Each daughter shares the same brother.', 'None of above.']
# A chess team has five players, and each player has one coach. But there are only six participants in the team. How is that possible?
# ['Each player shares the same coach.', 'Some players are backups and not allowed to play.', 'Some coaches get a raise.', 'None of above.']
# ...
